# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')
# Select the columns for cross tabulation
variables = ['educ', 'inc_q', 'emp_in']

# Create an empty dictionary to store the cross tabulations
cross_tabs = {}

# Perform cross tabulations for each variable
for variable in variables:
    cross_tabs[variable] = pd.crosstab(df['Gender'], df[variable])

# Display the cross tabulations
for variable, table in cross_tabs.items():
    print(f"Cross Tabulation for {variable}:")
    print(table)
    print()
    
import pandas as pd

# Assuming you have a DataFrame called 'data' with columns 'gender' and 'financial_inclusion'
df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')

# Select the columns for cross tabulation
variables = ['educ', 'inc_q', 'emp_in']

# Create an empty dictionary to store the cross tabulations
cross_tabs = {}

# Perform cross tabulations for each variable
for variable in variables:
    cross_tabs[variable] = pd.crosstab(df['Gender'], df[variable], normalize='index') * 100

# Print the cross-tabulations
# Display the cross tabulations
for variable, table in cross_tabs.items():
    print(f"Cross Tabulation in % for {variable}:")
    print(table)
    print()

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')

# Count the occurrences of each combination of gender and education
count_table = df.groupby(['Gender', 'educ']).size().unstack()

# Set the size of the graph
plt.figure(figsize=(16, 6))

# Plotting the graph
ax = count_table.plot(kind='bar', stacked=True)

# Adding labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender and Education Distribution')

# Move the legend to the top-right corner
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the plot
plt.show()

# Count the occurrences of each combination of gender and education
count_table = df.groupby(['Gender', 'inc_q']).size().unstack()

# Set the size of the graph
plt.figure(figsize=(16, 6))

# Plotting the graph
ax = count_table.plot(kind='bar', stacked=True)

# Adding labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender and Income Quartile Distribution')

# Move the legend to the top-right corner
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the plot
plt.show()

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')

# Count the occurrences of each combination of gender and education
count_table = df.groupby(['Gender', 'emp_in']).size().unstack()

# Set the size of the graph
plt.figure(figsize=(16, 6))

# Plotting the graph
ax = count_table.plot(kind='bar', stacked=True)

# Adding labels and title
plt.xlabel('Gender')
plt.ylabel('Count')
plt.title('Gender and Employment Distribution')

# Move the legend to the top-right corner
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the plot
plt.show()
# Out:
# Cross Tabulation for educ:
# educ    Primary School  Secondary School  Tertiary School
# Gender
# Female             567               177               17
# Male               410               201               31
#
# Cross Tabulation for inc_q:
# inc_q   Fourth 20%  Middle 20%  Poorest Second 20%0%  Richest 20%  Second 20%
# Gender
# Female         154         144                   154          188         121
# Male           148         125                   116          132         121
#
# Cross Tabulation for emp_in:
# emp_in  In Workforce  Out of the Workforce
# Gender
# Female            58                   703
# Male             443                   199
#
# Cross Tabulation in % for educ:
# educ    Primary School  Secondary School  Tertiary School
# Gender
# Female       74.507227         23.258870         2.233903
# Male         63.862928         31.308411         4.828660
#
# Cross Tabulation in % for inc_q:
# inc_q   Fourth 20%  Middle 20%  Poorest Second 20%0%  Richest 20%  Second 20%
# Gender
# Female   20.236531   18.922470             20.236531    24.704336   15.900131
# Male     23.052960   19.470405             18.068536    20.560748   18.847352
#
# Cross Tabulation in % for emp_in:
# emp_in  In Workforce  Out of the Workforce
# Gender
# Female      7.621551             92.378449
# Male       69.003115             30.996885

# %%
# Calculate summary statistics by gender
summary_stats = df.groupby('Gender')['age'].describe()

# Print the summary statistics
print(summary_stats)

# Following shows the age statistics wrt to the Gender

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')

# Assuming you have a DataFrame called 'data' with 'age' and 'gender' columns

# Create a box plot
sns.boxplot(x='Gender', y='age', data=df)

# Customize the plot
plt.xlabel('Gender')
plt.ylabel('Age')
plt.title('Box Plot of Age by Gender')

# Display the plot
plt.show()
# Out:
#         count       mean        std   min   25%   50%   75%   max
# Gender
# Female  761.0  33.512484  12.581321  15.0  24.0  30.0  40.0  80.0
# Male    642.0  35.065421  15.675296  15.0  23.0  32.0  45.0  99.0

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')
# Select the columns for cross tabulation
variables = ['fin11a', 'fin11b', 'fin11c', 'fin11d', 'fin11e', 'fin11f', 'fin11g', 'fin11h']

# Create an empty dictionary to store the cross tabulations
cross_tabs = {}

# Perform cross tabulations for each variable
for variable in variables:
    cross_tabs[variable] = pd.crosstab(df['Gender'], df[variable])

# Display the cross tabulations
for variable, table in cross_tabs.items():
    print(f"Cross Tabulation for {variable}:")
    print(table)
    print()
    
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')
# Select the columns for cross tabulation
variables = ['fin11a', 'fin11b', 'fin11c', 'fin11d', 'fin11e', 'fin11f', 'fin11g', 'fin11h']

# Create an empty dictionary to store the cross tabulations
cross_tabs = {}

# Perform cross tabulations for each variable
for variable in variables:
    cross_tabs[variable] = pd.crosstab(df['Gender'], df[variable], normalize='index') * 100

# Display the cross tabulations
for variable, table in cross_tabs.items():
    print(f"Cross Tabulation in % for {variable}:")
    print(table)
    print()
    
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')

# Mapping for color scheme labels (Response scheme)
color_labels_response = {
    1: 'Yes',
    2: 'No',
    3: "Don't know",
    4: 'Refused to answer'
}

# Create a new DataFrame with gender and variables of interest
df_gender_vars = df[['Gender', 'fin11a', 'fin11b', 'fin11c', 'fin11d', 'fin11e', 'fin11f', 'fin11g', 'fin11h']].copy()

# Replace numerical codes with labels for the response scheme
df_gender_vars.replace(color_labels_response, inplace=True)

# Reshape the DataFrame for plotting
df_gender_vars = pd.melt(df_gender_vars, id_vars='Gender', var_name='Variable', value_name='Response')

# Set the size of the graph
plt.figure(figsize=(10, 6))

# Plotting the graph
ax = sns.countplot(x='Variable', hue='Response', data=df_gender_vars, hue_order=color_labels_response.values())

# Adding labels and title
plt.xlabel('Reason For No Account')
plt.ylabel('Count')
plt.title('Reasons For No Account Distribution')

# Move the legend outside the graph
ax.legend(title='Response', loc='center left', bbox_to_anchor=(1.025, 0.25))

# Create a legend box below the graph for reasons of no account as text
legend_text = '''Reasons for no account:
fin11a - Reason for no account: too far
fin11b - Reason for no account: too expensive
fin11c - Reason for no account: lack documentation
fin11d - Reason for no account: lack trust
fin11e - Reason for no account: religious reasons
fin11f - Reason for no account: lack money
fin11g - Reason for no account: family member already has one
fin11h - Reason for no account: no need for financial services'''

plt.text(1.025, 0.5, legend_text, transform=ax.transAxes, fontsize=10)

# Display the plot
plt.show()
# Out:
# Cross Tabulation for fin11a:
# fin11a    1    2   3  4
# Gender
# Female  138  571  46  6
# Male    106  533   2  1
#
# Cross Tabulation for fin11b:
# fin11b    1    2   3  4
# Gender
# Female  169  517  70  5
# Male    131  482  29  0
#
# Cross Tabulation for fin11c:
# fin11c    1    2   3   4
# Gender
# Female  128  606  16  11
# Male    118  520   4   0
#
# Cross Tabulation for fin11d:
# fin11d   1    2   3   4
# Gender
# Female  94  603  52  12
# Male    93  545   4   0
#
# Cross Tabulation for fin11e:
# fin11e    1    2   3   4
# Gender
# Female  116  607  28  10
# Male     71  569   1   1
#
# Cross Tabulation for fin11f:
# fin11f    1    2   3   4
# Gender
# Female  393  343  14  11
# Male    309  326   2   5
#
# Cross Tabulation for fin11g:
# fin11g    1    2   3  4
# Gender
# Female  131  608  13  9
# Male     77  562   1  2
#
# Cross Tabulation for fin11h:
# fin11h    1    2   3  4
# Gender
# Female  185  552  17  7
# Male    206  434   1  1
#
# Cross Tabulation in % for fin11a:
# fin11a          1          2         3         4
# Gender
# Female  18.134034  75.032852  6.044678  0.788436
# Male    16.510903  83.021807  0.311526  0.155763
#
# Cross Tabulation in % for fin11b:
# fin11b          1          2         3        4
# Gender
# Female  22.207622  67.936925  9.198423  0.65703
# Male    20.404984  75.077882  4.517134  0.00000
#
# Cross Tabulation in % for fin11c:
# fin11c          1          2         3         4
# Gender
# Female  16.819974  79.632063  2.102497  1.445466
# Male    18.380062  80.996885  0.623053  0.000000
#
# Cross Tabulation in % for fin11d:
# fin11d          1          2         3         4
# Gender
# Female  12.352168  79.237845  6.833114  1.576873
# Male    14.485981  84.890966  0.623053  0.000000
#
# Cross Tabulation in % for fin11e:
# fin11e          1          2         3         4
# Gender
# Female  15.243101  79.763469  3.679369  1.314060
# Male    11.059190  88.629283  0.155763  0.155763
#
# Cross Tabulation in % for fin11f:
# fin11f          1          2         3         4
# Gender
# Female  51.642576  45.072273  1.839685  1.445466
# Male    48.130841  50.778816  0.311526  0.778816
#
# Cross Tabulation in % for fin11g:
# fin11g          1          2         3         4
# Gender
# Female  17.214192  79.894875  1.708279  1.182654
# Male    11.993769  87.538941  0.155763  0.311526
#
# Cross Tabulation in % for fin11h:
# fin11h          1          2         3         4
# Gender
# Female  24.310118  72.536137  2.233903  0.919842
# Male    32.087227  67.601246  0.155763  0.155763

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')

# Calculate mode and frequency
mode = df['FinancialInc'].mode().values[0]
frequency = df['FinancialInc'].value_counts(normalize=True) * 100

# Print the mode and frequency
print("Mode of Financial Inclusion:", mode)
print("\nFrequency of each category:")
print(frequency)
# Out:
# Mode of Financial Inclusion: Low
#
# Frequency of each category:
# Low         66.500356
# Moderate    30.648610
# High         2.565930
# 6            0.285103
# Name: FinancialInc, dtype: float64

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')
# Select the columns for cross tabulation
variables = ['Gender', 'educ', 'inc_q', 'emp_in']

# Create an empty dictionary to store the cross tabulations
cross_tabs = {}

# Perform cross tabulations for each variable
for variable in variables:
    cross_tabs[variable] = pd.crosstab(df['FinancialInc'], df[variable])

# Display the cross tabulations
for variable, table in cross_tabs.items():
    print(f"Cross Tabulation for {variable}:")
    print(table)
    print()
    
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')
# Select the columns for cross tabulation
variables = ['Gender', 'educ', 'inc_q', 'emp_in']

# Create an empty dictionary to store the cross tabulations
cross_tabs = {}

# Perform cross tabulations for each variable
for variable in variables:
    cross_tabs[variable] = pd.crosstab(df['FinancialInc'], df[variable], normalize='index') * 100

# Display the cross tabulations
for variable, table in cross_tabs.items():
    print(f"Cross Tabulation in % for {variable}:")
    print(table)
    print()
    
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')

# Count the occurrences of each combination of gender and education
count_table = df.groupby(['FinancialInc', 'Gender']).size().unstack()

# Set the size of the graph
plt.figure(figsize=(16, 6))

# Plotting the graph
ax = count_table.plot(kind='bar', stacked=True)

# Adding labels and title
plt.xlabel('Financial Inclusion')
plt.ylabel('Count')
plt.title('Financial Inclusion and Gender Distribution')

# Move the legend to the top-right corner
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the plot
plt.show()

# Count the occurrences of each combination of gender and education
count_table = df.groupby(['FinancialInc', 'educ']).size().unstack()

# Set the size of the graph
plt.figure(figsize=(16, 6))

# Plotting the graph
ax = count_table.plot(kind='bar', stacked=True)

# Adding labels and title
plt.xlabel('Financial Inclusion')
plt.ylabel('Count')
plt.title('Financial Inclusion and Education Distribution')

# Move the legend to the top-right corner
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the plot
plt.show()

# Count the occurrences of each combination of gender and education
count_table = df.groupby(['FinancialInc', 'inc_q']).size().unstack()

# Set the size of the graph
plt.figure(figsize=(16, 6))

# Plotting the graph
ax = count_table.plot(kind='bar', stacked=True)

# Adding labels and title
plt.xlabel('Financial Inclusion')
plt.ylabel('Count')
plt.title('Financial Inclusion and Income Quartile Distribution')

# Move the legend to the top-right corner
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the plot
plt.show()

# Count the occurrences of each combination of gender and education
count_table = df.groupby(['FinancialInc', 'emp_in']).size().unstack()

# Set the size of the graph
plt.figure(figsize=(16, 6))

# Plotting the graph
ax = count_table.plot(kind='bar', stacked=True)

# Adding labels and title
plt.xlabel('Financial Inclusion')
plt.ylabel('Count')
plt.title('Financial Inclusion and Employment Distribution')

# Move the legend to the top-right corner
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# Display the plot
plt.show()
# Out:
# Cross Tabulation for Gender:
# Gender        Female  Male
# FinancialInc
# 6                  0     4
# High               2    34
# Low              621   312
# Moderate         138   292
#
# Cross Tabulation for educ:
# educ          Primary School  Secondary School  Tertiary School
# FinancialInc
# 6                          0                 3                1
# High                      12                15                9
# Low                      671               233               29
# Moderate                 294               127                9
#
# Cross Tabulation for inc_q:
# inc_q         Fourth 20%  Middle 20%  Poorest Second 20%0%  Richest 20%  \
# FinancialInc
# 6                      1           1                     0            2
# High                   8           3                     7           14
# Low                  181         171                   191          215
# Moderate             112          94                    72           89
#
# inc_q         Second 20%
# FinancialInc
# 6                      0
# High                   4
# Low                  175
# Moderate              63
#
# Cross Tabulation for emp_in:
# emp_in        In Workforce  Out of the Workforce
# FinancialInc
# 6                        4                     0
# High                    27                     9
# Low                    235                   698
# Moderate               235                   195
#
# Cross Tabulation in % for Gender:
# Gender           Female        Male
# FinancialInc
# 6              0.000000  100.000000
# High           5.555556   94.444444
# Low           66.559486   33.440514
# Moderate      32.093023   67.906977
#
# Cross Tabulation in % for educ:
# educ          Primary School  Secondary School  Tertiary School
# FinancialInc
# 6                   0.000000         75.000000        25.000000
# High               33.333333         41.666667        25.000000
# Low                71.918542         24.973205         3.108253
# Moderate           68.372093         29.534884         2.093023
#
# Cross Tabulation in % for inc_q:
# inc_q         Fourth 20%  Middle 20%  Poorest Second 20%0%  Richest 20%  \
# FinancialInc
# 6              25.000000   25.000000              0.000000    50.000000
# High           22.222222    8.333333             19.444444    38.888889
# Low            19.399786   18.327974             20.471597    23.043944
# Moderate       26.046512   21.860465             16.744186    20.697674
#
# inc_q         Second 20%
# FinancialInc
# 6               0.000000
# High           11.111111
# Low            18.756699
# Moderate       14.651163
#
# Cross Tabulation in % for emp_in:
# emp_in        In Workforce  Out of the Workforce
# FinancialInc
# 6               100.000000              0.000000
# High             75.000000             25.000000
# Low              25.187567             74.812433
# Moderate         54.651163             45.348837

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')
# Select the columns for cross tabulation
variables = ['mobileowner']

# Create an empty dictionary to store the cross tabulations
cross_tabs = {}

# Perform cross tabulations for each variable
for variable in variables:
    cross_tabs[variable] = pd.crosstab(df['Gender'], df[variable])

# Display the cross tabulations
for variable, table in cross_tabs.items():
    print(f"Cross Tabulation for {variable}:")
    print(table)
    print()
    
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')
# Select the columns for cross tabulation
variables = ['mobileowner']

# Create an empty dictionary to store the cross tabulations
cross_tabs = {}

# Perform cross tabulations for each variable
for variable in variables:
    cross_tabs[variable] = pd.crosstab(df['Gender'], df[variable], normalize='index') * 100

# Display the cross tabulations
for variable, table in cross_tabs.items():
    print(f"Cross Tabulation in % for {variable}:")
    print(table)
    print()
# Out:
# Cross Tabulation for mobileowner:
# mobileowner    1    2
# Gender
# Female       258  503
# Male         486  156
#
# Cross Tabulation in % for mobileowner:
# mobileowner          1          2
# Gender
# Female       33.902760  66.097240
# Male         75.700935  24.299065

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')
# Select the columns for cross tabulation
variables = ['mobileowner']

# Create an empty dictionary to store the cross tabulations
cross_tabs = {}

# Perform cross tabulations for each variable
for variable in variables:
    cross_tabs[variable] = pd.crosstab(df['FinancialInc'], df[variable])

# Display the cross tabulations
for variable, table in cross_tabs.items():
    print(f"Cross Tabulation for {variable}:")
    print(table)
    print()
    
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv('C:/Users/LENOVO/Downloads/2017clean.csv')
# Select the columns for cross tabulation
variables = ['mobileowner']

# Create an empty dictionary to store the cross tabulations
cross_tabs = {}

# Perform cross tabulations for each variable
for variable in variables:
    cross_tabs[variable] = pd.crosstab(df['FinancialInc'], df[variable], normalize='index') * 100

# Display the cross tabulations
for variable, table in cross_tabs.items():
    print(f"Cross Tabulation in % for {variable}:")
    print(table)
    print()
# Out:
# Cross Tabulation for mobileowner:
# mobileowner     1    2
# FinancialInc
# 6               4    0
# High           34    2
# Low           413  520
# Moderate      293  137
#
# Cross Tabulation in % for mobileowner:
# mobileowner            1          2
# FinancialInc
# 6             100.000000   0.000000
# High           94.444444   5.555556
# Low            44.265809  55.734191
# Moderate       68.139535  31.860465
